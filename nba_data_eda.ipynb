# %%
import pandas as pd

# %matplotlib inline

# %%
nba2006 = pd.read_csv('./data/2006-2007_NBA_Box_Score_Team_Stats.csv')
nba2007 = pd.read_csv('./data/2007-2008_NBA_Box_Score_Team_Stats.csv')
nba2008 = pd.read_csv('./data/2008-2009_NBA_Box_Score_Team_Stats.csv')

# %%
nba2008.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2631 entries, 0 to 2630
# Data columns (total 50 columns):
# DATASET             2630 non-null object
# DATE                2630 non-null object
# TEAMS               2630 non-null object
# VENUE               2630 non-null object
# 1Q                  2630 non-null float64
# 2Q                  2630 non-null float64
# 3Q                  2630 non-null float64
# 4Q                  2630 non-null float64
# OT1                 154 non-null float64
# OT2                 30 non-null float64
# OT3                 6 non-null float64
# OT4                 0 non-null float64
# F                   2630 non-null float64
# MIN                 2630 non-null float64
# FG                  2630 non-null float64
# FGA                 2630 non-null float64
# 3P                  2630 non-null float64
# 3PA                 2630 non-null float64
# FT                  2630 non-null float64
# FTA                 2630 non-null float64
# OR                  2630 non-null float64
# DR                  2630 non-null float64
# TOT                 2630 non-null float64
# A                   2630 non-null float64
# PF                  2630 non-null float64
# ST                  2630 non-null float64
# TO                  2630 non-null float64
# BL                  2630 non-null float64
# PTS                 2630 non-null float64
# POSS                2630 non-null float64
# PACE                2630 non-null float64
# OEFF                2630 non-null float64
# DEFF                2630 non-null float64
# REST DAYS           2630 non-null object
# STARTING LINEUPS    2629 non-null object
# Unnamed: 35         2630 non-null object
# Unnamed: 36         2630 non-null object
# Unnamed: 37         2630 non-null object
# Unnamed: 38         2630 non-null object
# MAIN REFEREE        1315 non-null object
# CREW REFEREES       2630 non-null object
# OPENING ODDS        2630 non-null float64
# SPREAD              2630 non-null float64
# TOTAL               2630 non-null float64
# MOVEMENTS           2576 non-null object
# CLOSING             2630 non-null object
# MONEYLINE           2584 non-null float64
# HALFTIME            0 non-null float64
# BOX SCORE           1315 non-null object
# ODDS                1315 non-null object
# dtypes: float64(34), object(16)
# memory usage: 1.0+ MB

# %%
nba2006['DATE'].dropna(inplace = True)

# %%
nba2006.head(10).T
# Out:
#                                          0                         1  \
# DATASET           2006-2007 Regular Season  2006-2007 Regular Season
# DATE                              10/31/06                  10/31/06
# TEAMS                              Chicago                     Miami
# VENUE                                 Road                      Home
# 1Q                                      22                        16
# 2Q                                      37                        14
# 3Q                                      21                        21
# 4Q                                      28                        15
# OT1                                    NaN                       NaN
# OT2                                    NaN                       NaN
# OT3                                    NaN                       NaN
# OT4                                    NaN                       NaN
# F                                      108                        66
# MIN                                    240                       240
# FG                                      39                        25
# FGA                                     79                        65
# 3P                                       7                         3
# 3PA                                     13                        17
# FT                                      23                        13
# FTA                                     32                        22
# OR                                      13                         4
# DR                                      36                        25
# TOT                                     49                        29
# A                                       22                        13
# PF                                      21                        24
# ST                                      10                         6
# TO                                      16                        21
# BL                                       5                         3
# PTS                                    108                        66
# POSS                                  91.8                      91.8
# PACE                                  91.8                      91.8
# OEFF                                 117.6                      71.9
# DEFF                                  71.9                     117.6
# REST DAYS                               3+                        3+
# STARTING LINEUPS                 P. Brown                 U. Haslem
# Unnamed: 35                       L. Deng                 S. O'Neal
# Unnamed: 36                     B. Gordon                 G. Payton
# Unnamed: 37                    K. Hinrich                   D. Wade
# Unnamed: 38                     B. Wallace                 A. Walker
# MAIN REFEREE                 Not available                       NaN
# CREW REFEREES                 Bernie Fryer          Derek Richardson
# OPENING ODDS                           193                        -6
# SPREAD                                   6                        -6
# TOTAL                                  193                       193
# MOVEMENTS                  188.5/187.5/187                -6/-5.5/-5
# CLOSING                              186.5                      -4.5
# MONEYLINE                              170                      -200
# HALFTIME                               NaN                       NaN
# BOX SCORE                              NaN                  Boxscore
# ODDS                                   NaN                      Odds
#
#                                          2                         3  \
# DATASET           2006-2007 Regular Season  2006-2007 Regular Season
# DATE                              10/31/06                  10/31/06
# TEAMS                              Phoenix                 LA Lakers
# VENUE                                 Road                      Home
# 1Q                                      41                        26
# 2Q                                      17                        27
# 3Q                                      21                        34
# 4Q                                      27                        27
# OT1                                    NaN                       NaN
# OT2                                    NaN                       NaN
# OT3                                    NaN                       NaN
# OT4                                    NaN                       NaN
# F                                      106                       114
# MIN                                    240                       240
# FG                                      40                        46
# FGA                                     77                        83
# 3P                                      13                         6
# 3PA                                     30                        12
# FT                                      13                        16
# FTA                                     17                        24
# OR                                       4                        12
# DR                                      25                        31
# TOT                                     29                        43
# A                                       29                        30
# PF                                      25                        19
# ST                                       7                        11
# TO                                      21                        20
# BL                                       5                         1
# PTS                                    106                       114
# POSS                                   100                       100
# PACE                                   100                       100
# OEFF                                   106                       114
# DEFF                                   114                       106
# REST DAYS                               3+                        3+
# STARTING LINEUPS                  R. Bell                  A. Bynum
# Unnamed: 35                       B. Diaw                   L. Odom
# Unnamed: 36                     S. Marion                 S. Parker
# Unnamed: 37                       S. Nash                S. Vujacic
# Unnamed: 38                      K. Thomas                 L. Walton
# MAIN REFEREE                   Steve Javie                       NaN
# CREW REFEREES               Tom Washington                Eric Lewis
# OPENING ODDS                            -6                       205
# SPREAD                                  -6                         6
# TOTAL                                  205                       205
# MOVEMENTS                    -8/-8-15/-8.5           207.5/207/206.5
# CLOSING                              -8-15                       207
# MONEYLINE                             -380                       310
# HALFTIME                               NaN                       NaN
# BOX SCORE                              NaN                  Boxscore
# ODDS                                   NaN                      Odds
#
#                                          4                         5  \
# DATASET           2006-2007 Regular Season  2006-2007 Regular Season
# DATE                              11/01/06                  11/01/06
# TEAMS                              Indiana                 Charlotte
# VENUE                                 Road                      Home
# 1Q                                      23                        27
# 2Q                                      26                        23
# 3Q                                      28                        23
# 4Q                                      29                        26
# OT1                                    NaN                       NaN
# OT2                                    NaN                       NaN
# OT3                                    NaN                       NaN
# OT4                                    NaN                       NaN
# F                                      106                        99
# MIN                                    240                       240
# FG                                      35                        37
# FGA                                     86                        78
# 3P                                       6                         4
# 3PA                                     16                        10
# FT                                      30                        21
# FTA                                     41                        32
# OR                                      18                        11
# DR                                      32                        35
# TOT                                     50                        46
# A                                       26                        23
# PF                                      26                        29
# ST                                      14                         8
# TO                                      17                        22
# BL                                       5                         7
# PTS                                    106                        99
# POSS                                 101.2                     101.2
# PACE                                 101.2                     101.2
# OEFF                                 104.7                      97.8
# DEFF                                  97.8                     104.7
# REST DAYS                               3+                        3+
# STARTING LINEUPS               D. Granger                 R. Felton
# Unnamed: 35                 A. Harrington                 B. Knight
# Unnamed: 36                    S. Jackson                    S. May
# Unnamed: 37                     J. O'Neal                 E. Okafor
# Unnamed: 38                     J. Tinsley                G. Wallace
# MAIN REFEREE                   David Jones                       NaN
# CREW REFEREES                      Eli Roe             Not available
# OPENING ODDS                            -3                       194
# SPREAD                                  -3                         3
# TOTAL                                  194                       194
# MOVEMENTS                         PK/-1/PK           193.5/193/193.5
# CLOSING                                 -1                       193
# MONEYLINE                              NaN                       NaN
# HALFTIME                               NaN                       NaN
# BOX SCORE                              NaN                  Boxscore
# ODDS                                   NaN                      Odds
#
#                                          6                         7  \
# DATASET           2006-2007 Regular Season  2006-2007 Regular Season
# DATE                              11/01/06                  11/01/06
# TEAMS                              Chicago                   Orlando
# VENUE                                 Road                      Home
# 1Q                                      20                        32
# 2Q                                      25                        31
# 3Q                                      25                        23
# 4Q                                      24                        23
# OT1                                    NaN                       NaN
# OT2                                    NaN                       NaN
# OT3                                    NaN                       NaN
# OT4                                    NaN                       NaN
# F                                       94                       109
# MIN                                    240                       240
# FG                                      37                        35
# FGA                                     82                        59
# 3P                                       6                         6
# 3PA                                     20                         8
# FT                                      14                        33
# FTA                                     24                        42
# OR                                      11                         6
# DR                                      16                        30
# TOT                                     27                        36
# A                                       21                        21
# PF                                      31                        23
# ST                                       7                         7
# TO                                      15                        23
# BL                                       0                         7
# PTS                                     94                       109
# POSS                                  92.7                      92.7
# PACE                                  92.7                      92.7
# OEFF                                 101.4                     117.5
# DEFF                                 117.5                     101.4
# REST DAYS                              B2B                        3+
# STARTING LINEUPS                 P. Brown                 T. Battie
# Unnamed: 35                       L. Deng                   G. Hill
# Unnamed: 36                     B. Gordon                 D. Howard
# Unnamed: 37                    K. Hinrich                 J. Nelson
# Unnamed: 38                     B. Wallace               H. Turkoglu
# MAIN REFEREE                 Ron Garretson                       NaN
# CREW REFEREES                Michael Smith             Not available
# OPENING ODDS                           187                      -2.5
# SPREAD                                 2.5                      -2.5
# TOTAL                                  187                       187
# MOVEMENTS                       +2.5/+3/-2             186/185.5/184
# CLOSING                               -1.5                     183.5
# MONEYLINE                             -125                       105
# HALFTIME                               NaN                       NaN
# BOX SCORE                              NaN                  Boxscore
# ODDS                                   NaN                      Odds
#
#                                          8                         9
# DATASET           2006-2007 Regular Season  2006-2007 Regular Season
# DATE                              11/01/06                  11/01/06
# TEAMS                              Atlanta              Philadelphia
# VENUE                                 Road                      Home
# 1Q                                      14                        29
# 2Q                                      21                        20
# 3Q                                      23                        24
# 4Q                                      17                        15
# OT1                                    NaN                       NaN
# OT2                                    NaN                       NaN
# OT3                                    NaN                       NaN
# OT4                                    NaN                       NaN
# F                                       75                        88
# MIN                                    240                       240
# FG                                      26                        31
# FGA                                     78                        74
# 3P                                       4                         3
# 3PA                                     17                         9
# FT                                      19                        23
# FTA                                     22                        25
# OR                                      17                        15
# DR                                      25                        32
# TOT                                     42                        47
# A                                       11                        19
# PF                                      24                        22
# ST                                       9                        10
# TO                                      18                        16
# BL                                       4                         6
# PTS                                     75                        88
# POSS                                  84.1                      84.1
# PACE                                  84.1                      84.1
# OEFF                                  89.2                     104.6
# DEFF                                 104.6                      89.2
# REST DAYS                               3+                        3+
# STARTING LINEUPS               S. Claxton              S. Dalembert
# Unnamed: 35                    J. Johnson               A. Iguodala
# Unnamed: 36                   Z. Pachulia                A. Iverson
# Unnamed: 37                      J. Smith                  K. Ollie
# Unnamed: 38                    S. Williams                 C. Webber
# MAIN REFEREE                 Not available                       NaN
# CREW REFEREES             Derek Richardson             Not available
# OPENING ODDS                         200.5                        -7
# SPREAD                                   7                        -7
# TOTAL                                200.5                     200.5
# MOVEMENTS                    198.5/199/200              -6.5/-5.5/-6
# CLOSING                                199                      -5.5
# MONEYLINE                              200                      -240
# HALFTIME                               NaN                       NaN
# BOX SCORE                              NaN                  Boxscore
# ODDS                                   NaN                      Odds

# %% [markdown]
# ### NBA csv File Structure
#
# Currently, the NBA data has two records for each game one with the home team data and one with the away team data.  The unit of analysis for this study is the game so the data needs to be rearranged to use the game as the unit of analysis.  Therefore, each even row must be appended to the odd row above it to make the game the unit of analysis

# %%
def merge_home_away(df):
    
    #make all column names lower snake case
    df.columns = [col.lower().replace(' ', '_') for col in df.columns]
    
    #replace missing data with zeros
    missing_list = ['ot1', 'ot2', 'ot3', 'ot4']
    
    
    #some missing moneylines going to set them to zero for now look explore later
    df['moneyline'].fillna(0, inplace = True)
    df['movements'].fillna('none', inplace = True)
    
    
    for ot in missing_list:
        df[ot].fillna(0, inplace = True)
    
    
    #split up the rows
    df1 =  df[df.index %2 == 0]
    df2 = df[df.index %2 == 1] 
    
    #drop unnessecary columns in df1
    
    df1.drop(columns = ['box_score', 
                        'odds',
                        'halftime'])
    
    #drop redunant columns in df2
    df2.drop(columns = ['dataset',
                        'date',
                        'venue', 
                        'pts', 
                        'poss', 
                        'pace', 
                        'box_score', 
                        'odds',
                        'opening_odds', 
                        'main_referee',
                        'halftime'], inplace = True)
    
    
    #rename columns df2 
    away =  {'teams'     : 'away_team',
             '1q'        : 'away_1q',
             '2q'        : 'away_2q',
             '3q'        : 'away_3q',
             '4q'        : 'away_4q',
             'ot1'       : 'away_ot1',
             'ot2'       : 'away_ot2',
             'ot3'       : 'away_ot3',
             'ot4'       : 'away_ot4',
             'f'         : 'away_score',
             'min'       : 'away_min',
             'fg'        : 'away_fg',
             'fga'       : 'away_fga',
             '3p'        : 'away_3p',
             '3pa'       : 'away_3pa',
             'ft'        : 'away_ft',
             'fta'       : 'away_fta',
             'or'        : 'away_or',
             'dr'        : 'away_dr',
             'tot'       : 'away_total_reb',
             'a'         : 'away_assists',
             'pf'        : 'away_fouls',
             'st'        : 'away_steals',
             'or'        : 'away_or',
             'to'        : 'away_turnovers',
             'bl'        : 'away_blocks',
             'poss'      : 'away_poss',
             'pace'      : 'away_pace',
             'oeff'      : 'away_off_eff',
             'deff'      : 'away_def_eff',
             'rest_days' : 'away_rest',
             'starting_lineup' : 'away_starter1',
             'unnamed:_35'     : 'away_starter2',
             'unnamed:_36'     : 'away_starter3',
             'unnamed:_37'     : 'away_starter4',
             'unnamed:_38'     : 'away_starter5',
             'crew_referees'   : 'ref_3',
             'spread'          : 'away_line',
             'total'           : 'away_total',
             'movements'       : 'total_moves',
             'closing'         : 'closing total',
             'moneyline'       : 'away_moneyline'
             }
    df2.rename(columns = away, inplace = True)
    
    #reset the indexs to merge the files
    df1.reset_index(inplace = True)
    df2.reset_index(inplace = True)
                         
    #merge data so game becomes rather than team unit of analysis                      
    new =  pd.concat([df1,df2], axis = 1)
    
    #call second function
    new2 = create_home_mov_ave(new)
    new3 = create_away_mov_ave(new2)

# %%
def create_home_mov_ave(df):
    

    
    #add underscores to teams
    df['teams'] = [str(team).replace(' ', '_') for team in df['teams']]
    
    #loop through teams
    teams = ['Atlanta','Boston','Charlotte','Chicago',
             'Cleveland','Dallas','Denver','Detroit',
             'Golden_State','Houston','Indiana','LA_Clippers',
             'LA_Lakers','Memphis','Miami','Milwaukee',
             'Minnesota','New_Jersey','New_Orleans','New_York',
             'Orlando','Philadelphia','Phoenix','Portland',
             'Sacramento','San_Antonio','Seattle','Toronto',
             'Utah','Washington']
    

    columns = ['1q', '2q', '3q', '4q',
               'ot1', 'ot2', 'ot3', 'ot4', 'f', 'min', 'fg', 
               'fga', '3p', '3pa', 'ft','fta', 'or', 'dr', 'tot', 
               'a', 'pf', 'st', 'to', 'pts', 'poss',
               'pace', 'oeff', 'deff', 'bl']
    #create empty data frame to put in results
    home_vars = pd.DataFrame()
    
    for team in teams:
        print(team)
        df_team = df[df['teams'] == team]
        
        for column in columns:
            column_new = 'mov_5_' + column
            df_team[column_new] = df_team[column].rolling(5).mean().shift(1)
        
        home_vars = home_vars.append(df_team)
    
        
    return home_vars

# %%
def create_away_mov_ave(df):
    

    
    #add underscores to teams
    df['away_team'] = [str(team).replace(' ', '_') for team in df['away_team']]
    
    #loop through teams
    teams = ['Atlanta','Boston','Charlotte','Chicago',
             'Cleveland','Dallas','Denver','Detroit',
             'Golden_State','Houston','Indiana','LA_Clippers',
             'LA_Lakers','Memphis','Miami','Milwaukee',
             'Minnesota','New_Jersey','New_Orleans','New_York',
             'Orlando','Philadelphia','Phoenix','Portland',
             'Sacramento','San_Antonio','Seattle','Toronto',
             'Utah','Washington']
    

    columns = ['away_1q', 'away_2q', 'away_3q', 'away_4q',
               'away_ot1', 'away_ot2', 'away_ot3', 'away_ot4', 
               'away_score', 'away_min', 'away_fg', 'away_fga', 
               'away_3p', 'away_3pa', 'away_ft','away_fta',
               'away_or', 'away_dr', 'away_total_reb', 
               'away_assists', 'away_fouls', 'away_steals', 
               'away_turnovers','away_blocks', 
               'away_off_eff',
               'away_def_eff']
    #create empty data frame to put in results
    away_vars = pd.DataFrame()
    
    for team in teams:
        print(team)
        df_team = df[df['away_team'] == team]
        
        for column in columns:
            column_new = 'mov_5_' + column
            df_team[column_new] = df_team[column].rolling(5).mean().shift(1)
        
        away_vars = away_vars.append(df_team)
    
        
    return away_vars

# %%
nba2006_trans = merge_home_away(nba2006)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-64aed2a705f3> in <module>()
# ----> 1 nba2006_trans = merge_home_away(nba2006)
#
# <ipython-input-21-900edd7ec3a4> in merge_home_away(df)
#      11
#      12     #some missing moneylines going to set them to zero for now look explore later
# ---> 13     df['moneyline'].fillna(0, inplace = true)
#      14     df['movements'].fillna('none')
#      15
#
# NameError: name 'true' is not defined

# %%
nba2006_trans['line_cv'] = nba2006_trans.away_score - nba2006_trans.f - nba2006_trans.spread

# %%
nba2006_trans.head(10).T
# Out:
#                                           556                       1159  \
# index                                     1112                      2318
# dataset               2006-2007 Regular Season  2006-2007 Regular Season
# date                                  01/15/07                  04/10/07
# teams                                   Boston                    Boston
# venue                                     Road                      Road
# 1q                                          15                        28
# 2q                                          25                        31
# 3q                                          26                        19
# 4q                                          30                        18
# ot1                                        NaN                       NaN
# ot2                                        NaN                       NaN
# ot3                                        NaN                       NaN
# ot4                                        NaN                       NaN
# f                                           96                        96
# min                                        240                       240
# fg                                          34                        36
# fga                                         75                        78
# 3p                                           9                         8
# 3pa                                         17                        16
# ft                                          19                        16
# fta                                         23                        20
# or                                          12                        11
# dr                                          26                        16
# tot                                         38                        27
# a                                           16                        18
# pf                                          23                        22
# st                                           7                         7
# to                                          20                        11
# bl                                           6                         2
# pts                                         96                        96
# ...                                        ...                       ...
# mov_3_oeff                                97.8                   94.0667
# mov_3_deff                               100.7                     101.8
# mov_3_bl                                     6                   2.33333
# mov_3_away_1q                              NaN                       NaN
# mov_3_away_2q                              NaN                       NaN
# mov_3_away_3q                              NaN                       NaN
# mov_3_away_4q                              NaN                       NaN
# mov_3_away_ot1                             NaN                       NaN
# mov_3_away_ot2                             NaN                       NaN
# mov_3_away_ot3                             NaN                       NaN
# mov_3_away_ot4                             NaN                       NaN
# mov_3_away_score                           NaN                       NaN
# mov_3_away_min                             NaN                       NaN
# mov_3_away_fg                              NaN                       NaN
# mov_3_away_fga                             NaN                       NaN
# mov_3_away_3p                              NaN                       NaN
# mov_3_away_3pa                             NaN                       NaN
# mov_3_away_ft                              NaN                       NaN
# mov_3_away_fta                             NaN                       NaN
# mov_3_away_or                              NaN                       NaN
# mov_3_away_dr                              NaN                       NaN
# mov_3_away_total_reb                       NaN                       NaN
# mov_3_away_assists                         NaN                       NaN
# mov_3_away_fouls                           NaN                       NaN
# mov_3_away_steals                          NaN                       NaN
# mov_3_away_turnovers                       NaN                       NaN
# mov_3_away_blocks                          NaN                       NaN
# mov_3_away_off_eff                         NaN                       NaN
# mov_3_away_def_eff                         NaN                       NaN
# line_cv                                     -2                         5
#
#                                           212                       583   \
# index                                      424                      1166
# dataset               2006-2007 Regular Season  2006-2007 Regular Season
# date                                  11/29/06                  01/19/07
# teams                                Charlotte                 Charlotte
# venue                                     Road                      Road
# 1q                                          16                        21
# 2q                                          25                        32
# 3q                                          31                        22
# 4q                                          18                        21
# ot1                                        NaN                       NaN
# ot2                                        NaN                       NaN
# ot3                                        NaN                       NaN
# ot4                                        NaN                       NaN
# f                                           90                        96
# min                                        240                       240
# fg                                          30                        39
# fga                                         82                        81
# 3p                                           4                         4
# 3pa                                         17                        17
# ft                                          26                        14
# fta                                         33                        22
# or                                          15                        15
# dr                                          22                        32
# tot                                         37                        47
# a                                           20                        20
# pf                                          20                        22
# st                                           7                         6
# to                                           7                        12
# bl                                           3                         5
# pts                                         90                        96
# ...                                        ...                       ...
# mov_3_oeff                             99.0667                   109.833
# mov_3_deff                                 106                   113.633
# mov_3_bl                               4.33333                   5.33333
# mov_3_away_1q                              NaN                   21.6667
# mov_3_away_2q                              NaN                   29.6667
# mov_3_away_3q                              NaN                        27
# mov_3_away_4q                              NaN                   22.6667
# mov_3_away_ot1                             NaN                       NaN
# mov_3_away_ot2                             NaN                       NaN
# mov_3_away_ot3                             NaN                       NaN
# mov_3_away_ot4                             NaN                       NaN
# mov_3_away_score                           NaN                       101
# mov_3_away_min                             NaN                       240
# mov_3_away_fg                              NaN                        39
# mov_3_away_fga                             NaN                        75
# mov_3_away_3p                              NaN                   4.66667
# mov_3_away_3pa                             NaN                        13
# mov_3_away_ft                              NaN                   18.3333
# mov_3_away_fta                             NaN                        22
# mov_3_away_or                              NaN                        12
# mov_3_away_dr                              NaN                        29
# mov_3_away_total_reb                       NaN                        41
# mov_3_away_assists                         NaN                   21.3333
# mov_3_away_fouls                           NaN                        20
# mov_3_away_steals                          NaN                   6.66667
# mov_3_away_turnovers                       NaN                   16.6667
# mov_3_away_blocks                          NaN                   8.33333
# mov_3_away_off_eff                         NaN                     116.8
# mov_3_away_def_eff                         NaN                   108.633
# line_cv                                    5.5                       -25
#
#                                           340                       1087  \
# index                                      680                      2174
# dataset               2006-2007 Regular Season  2006-2007 Regular Season
# date                                  12/16/06                  04/01/07
# teams                                  Chicago                   Chicago
# venue                                     Road                      Road
# 1q                                          24                        32
# 2q                                          27                        20
# 3q                                          24                        23
# 4q                                          18                        30
# ot1                                         13                       NaN
# ot2                                        NaN                       NaN
# ot3                                        NaN                       NaN
# ot4                                        NaN                       NaN
# f                                          106                       105
# min                                        265                       240
# fg                                          35                        40
# fga                                         78                        85
# 3p                                           8                         4
# 3pa                                         15                        12
# ft                                          28                        21
# fta                                         39                        26
# or                                          13                        12
# dr                                          33                        27
# tot                                         46                        39
# a                                           19                        18
# pf                                          18                        21
# st                                           6                         8
# to                                          18                        12
# bl                                           5                         9
# pts                                        106                       105
# ...                                        ...                       ...
# mov_3_oeff                             110.967                   102.633
# mov_3_deff                               111.3                   101.867
# mov_3_bl                                     4                   5.33333
# mov_3_away_1q                          21.3333                        22
# mov_3_away_2q                               28                   28.6667
# mov_3_away_3q                          22.6667                   20.3333
# mov_3_away_4q                          20.6667                        18
# mov_3_away_ot1                             NaN                       NaN
# mov_3_away_ot2                             NaN                       NaN
# mov_3_away_ot3                             NaN                       NaN
# mov_3_away_ot4                             NaN                       NaN
# mov_3_away_score                       92.6667                   92.6667
# mov_3_away_min                             240                   248.333
# mov_3_away_fg                               36                        36
# mov_3_away_fga                         73.3333                        81
# mov_3_away_3p                          3.66667                         5
# mov_3_away_3pa                         11.3333                   16.6667
# mov_3_away_ft                               17                   15.6667
# mov_3_away_fta                         20.6667                   20.3333
# mov_3_away_or                          9.33333                   10.3333
# mov_3_away_dr                               29                   28.3333
# mov_3_away_total_reb                   38.3333                   38.6667
# mov_3_away_assists                          18                   19.3333
# mov_3_away_fouls                       19.6667                        24
# mov_3_away_steals                      5.66667                   7.66667
# mov_3_away_turnovers                   14.3333                   13.6667
# mov_3_away_blocks                      6.66667                   6.66667
# mov_3_away_off_eff                       109.4                     103.4
# mov_3_away_def_eff                       111.1                   108.967
# line_cv                                      1                        -3
#
#                                           226                       413   \
# index                                      452                       826
# dataset               2006-2007 Regular Season  2006-2007 Regular Season
# date                                  12/01/06                  12/27/06
# teams                                Cleveland                 Cleveland
# venue                                     Road                      Road
# 1q                                          32                        28
# 2q                                          30                        22
# 3q                                          17                        16
# 4q                                          27                        23
# ot1                                        NaN                       NaN
# ot2                                        NaN                       NaN
# ot3                                        NaN                       NaN
# ot4                                        NaN                       NaN
# f                                          106                        89
# min                                        240                       240
# fg                                          41                        34
# fga                                         78                        78
# 3p                                           7                         3
# 3pa                                         16                         6
# ft                                          17                        18
# fta                                         29                        24
# or                                          13                        12
# dr                                          29                        33
# tot                                         42                        45
# a                                           20                        13
# pf                                          22                        16
# st                                           7                        13
# to                                          15                        19
# bl                                           3                         8
# pts                                        106                        89
# ...                                        ...                       ...
# mov_3_oeff                             103.233                   104.767
# mov_3_deff                               114.6                     110.7
# mov_3_bl                               2.66667                         2
# mov_3_away_1q                               26                   27.6667
# mov_3_away_2q                          24.6667                   26.6667
# mov_3_away_3q                               17                   20.6667
# mov_3_away_4q                          20.6667                        20
# mov_3_away_ot1                             NaN                       NaN
# mov_3_away_ot2                             NaN                       NaN
# mov_3_away_ot3                             NaN                       NaN
# mov_3_away_ot4                             NaN                       NaN
# mov_3_away_score                            92                   98.6667
# mov_3_away_min                         248.333                   248.333
# mov_3_away_fg                          35.6667                   36.3333
# mov_3_away_fga                              81                        80
# mov_3_away_3p                          3.33333                   4.66667
# mov_3_away_3pa                              12                   14.3333
# mov_3_away_ft                          17.3333                   21.3333
# mov_3_away_fta                         23.3333                   27.6667
# mov_3_away_or                          10.6667                   10.6667
# mov_3_away_dr                          26.6667                        27
# mov_3_away_total_reb                   37.3333                   37.6667
# mov_3_away_assists                          18                   18.6667
# mov_3_away_fouls                       23.3333                        26
# mov_3_away_steals                      8.33333                         8
# mov_3_away_turnovers                        14                   14.6667
# mov_3_away_blocks                      6.66667                   6.33333
# mov_3_away_off_eff                        99.9                     105.5
# mov_3_away_def_eff                     111.833                   113.167
# line_cv                                     -8                      -9.5
#
#                                           1034                      308
# index                                     2068                       616
# dataset               2006-2007 Regular Season  2006-2007 Regular Season
# date                                  03/25/07                  12/12/06
# teams                                   Dallas                    Denver
# venue                                     Road                      Road
# 1q                                          39                        22
# 2q                                          19                        21
# 3q                                          17                        28
# 4q                                          29                        29
# ot1                                        NaN                       NaN
# ot2                                        NaN                       NaN
# ot3                                        NaN                       NaN
# ot4                                        NaN                       NaN
# f                                          104                       100
# min                                        240                       240
# fg                                          36                        37
# fga                                         68                        75
# 3p                                           7                         7
# 3pa                                         13                        18
# ft                                          25                        19
# fta                                         30                        26
# or                                           5                        10
# dr                                          34                        36
# tot                                         39                        46
# a                                           23                        28
# pf                                          32                        24
# st                                           9                        10
# to                                          16                        21
# bl                                           3                         6
# pts                                        104                       100
# ...                                        ...                       ...
# mov_3_oeff                               114.5                   106.533
# mov_3_deff                             100.167                   105.967
# mov_3_bl                               5.66667                   3.33333
# mov_3_away_1q                               25                        21
# mov_3_away_2q                          23.3333                   23.3333
# mov_3_away_3q                               21                        23
# mov_3_away_4q                               20                        22
# mov_3_away_ot1                             NaN                       NaN
# mov_3_away_ot2                             NaN                       NaN
# mov_3_away_ot3                             NaN                       NaN
# mov_3_away_ot4                             NaN                       NaN
# mov_3_away_score                       89.3333                   89.3333
# mov_3_away_min                             240                       240
# mov_3_away_fg                               33                   30.3333
# mov_3_away_fga                              76                   72.6667
# mov_3_away_3p                          3.33333                   2.66667
# mov_3_away_3pa                         12.6667                        11
# mov_3_away_ft                               20                        26
# mov_3_away_fta                              25                   32.6667
# mov_3_away_or                          10.3333                   9.33333
# mov_3_away_dr                               27                        27
# mov_3_away_total_reb                   37.3333                   36.3333
# mov_3_away_assists                     15.6667                   15.3333
# mov_3_away_fouls                            23                   22.6667
# mov_3_away_steals                      9.33333                   10.3333
# mov_3_away_turnovers                        17                   15.6667
# mov_3_away_blocks                            6                         3
# mov_3_away_off_eff                        97.6                   98.0333
# mov_3_away_def_eff                     109.233                   109.333
# line_cv                                      3                      -7.5
#
# [149 rows x 10 columns]

# %%
nba2006_trans['cover'] = nba2006_trans['line_cv'].map(lambda x: 1 if x >0 else 0)

# %%
nba2006_trans.cover.value_counts(normalize = True)
# Out:
# 0    0.537051
# 1    0.462949
# Name: cover, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.grid_search import GridSearchCV
ad = AdaBoostClassifier()
ad_params = {'n_estimators' : [40, 50, 30],
             'learning_rate' : [.6,.7,.8]
             }

features = ['spread','mov_3_1q', 'mov_3_2q', 'mov_3_3q', 'mov_3_4q', 
         
            'mov_3_f', 'mov_3_min', 'mov_3_fg', 'mov_3_fga',
            'mov_3_3p', 'mov_3_3pa', 'mov_3_ft', 'mov_3_fta', 'mov_3_or',
            'mov_3_dr', 'mov_3_tot', 'mov_3_a', 'mov_3_pf', 'mov_3_st', 
            'mov_3_to',
       'mov_3_pts', 'mov_3_poss', 'mov_3_pace', 'mov_3_oeff','mov_3_deff', 
            'mov_3_bl',
       'mov_3_away_1q', 'mov_3_away_2q',
       'mov_3_away_3q', 'mov_3_away_4q' , 'mov_3_away_score',
       'mov_3_away_min', 'mov_3_away_fg', 'mov_3_away_fga', 'mov_3_away_3p',
       'mov_3_away_3pa', 'mov_3_away_ft', 'mov_3_away_fta', 'mov_3_away_or',
       'mov_3_away_dr', 'mov_3_away_total_reb', 'mov_3_away_assists', 'mov_3_away_fouls',
       'mov_3_away_steals', 'mov_3_away_turnovers', 'mov_3_away_blocks',
       'mov_3_away_off_eff', 'mov_3_away_def_eff', 'cover']

rid = nba2006_trans[features].dropna()

features2 = ['spread','mov_3_1q', 'mov_3_2q', 'mov_3_3q', 'mov_3_4q', 
             
            'mov_3_f', 'mov_3_min', 'mov_3_fg', 'mov_3_fga',
            'mov_3_3p', 'mov_3_3pa', 'mov_3_ft', 'mov_3_fta', 'mov_3_or',
            'mov_3_dr', 'mov_3_tot', 'mov_3_a', 'mov_3_pf', 'mov_3_st', 
            'mov_3_to',
       'mov_3_pts', 'mov_3_poss', 'mov_3_pace', 'mov_3_oeff','mov_3_deff', 
            'mov_3_bl',
       'mov_3_away_1q', 'mov_3_away_2q',
       'mov_3_away_3q', 'mov_3_away_4q', 
       'mov_3_away_min', 'mov_3_away_fg', 'mov_3_away_fga', 'mov_3_away_3p',
       'mov_3_away_3pa', 'mov_3_away_ft', 'mov_3_away_fta', 'mov_3_away_or',
       'mov_3_away_dr', 'mov_3_away_total_reb', 'mov_3_away_assists', 'mov_3_away_fouls',
       'mov_3_away_steals', 'mov_3_away_turnovers', 'mov_3_away_blocks',
       'mov_3_away_off_eff', 'mov_3_away_def_eff']


X = rid[features2]
y = rid['cover']
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
from sklearn.cross_validation import train_test_split, cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
gs = GridSearchCV(ad, 
                  param_grid=ad_params,
                  scoring= "accuracy")

gs.fit(X_train,y_train)
gs.best_score_
# Out:
# 0.5134818288393904

# %%
gs.best_params_
# Out:
# {'learning_rate': 0.6, 'n_estimators': 30}

# %%
y_hat_train = gs.predict(X_train)
y_hat_test = gs.predict(X_test)
y_hat_train_proba = gs.predict_proba(X_train)
y_hat_test_proba  = gs.predict_proba(X_test)

# %%
cross_val_score(ad,X_train, y_train, cv = 4)
# Out:
# array([0.43457944, 0.42723005, 0.4600939 , 0.50704225])

# %%
gs.score(X_test, y_test)
# Out:
# 0.5052631578947369

# %%
rid.cover.value_counts(normalize = True)
# Out:
# 0    0.540422
# 1    0.459578
# Name: cover, dtype: float64

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report( y_train, y_hat_train))

print(classification_report( y_test, y_hat_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.63      0.86      0.73       460
#           1       0.71      0.42      0.53       393
#
# avg / total       0.67      0.66      0.64       853
#
#              precision    recall  f1-score   support
#
#           0       0.53      0.72      0.61       155
#           1       0.43      0.25      0.31       130
#
# avg / total       0.48      0.51      0.48       285

# %%
#modifying train and testing data to allow for changing prob thresholds and printing the 
#roc curves
X_train.loc[:, 'actual_y'] = y_train
X_train.loc[:, 'predicted_label'] = y_hat_train
X_train.loc[:, 'predicted_proba'] = y_hat_train_proba[:, 1]
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
X_test.loc[:, 'actual_y'] = y_test
X_test.loc[:, 'predicted_label'] = y_hat_test
X_test.loc[:, 'predicted_proba'] = y_hat_test_proba[:, 1]
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#print out confusion matrices from .1 .5 by .02 for Xtest and Xtrain
for prob in range(490, 500, 1):
    proba = prob/1000
    
    X_test.loc[:, 'predicted_label']= X_test['predicted_proba'].map(
    lambda p: 1 if p > proba else 0)
    
    X_train.loc[:, 'predicted_label']= X_train['predicted_proba'].map(
    lambda p: 1 if p > proba else 0)
    
    X_test['predicted_label']
    print('Test  ' + str(proba))
    print(confusion_matrix(y_test, X_test['predicted_label']))
    print(' Train  ' + str(proba))
    print(confusion_matrix(y_train, X_train['predicted_label']))
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# Test  0.49
# [[ 10 136]
#  [ 17 122]]
#  Train  0.49
# [[ 80 389]
#  [ 15 369]]
# Test  0.491
# [[ 13 133]
#  [ 23 116]]
#  Train  0.491
# [[109 360]
#  [ 25 359]]
# Test  0.492
# [[ 16 130]
#  [ 25 114]]
#  Train  0.492
# [[120 349]
#  [ 27 357]]
# Test  0.493
# [[ 24 122]
#  [ 33 106]]
#  Train  0.493
# [[147 322]
#  [ 35 349]]
# Test  0.494
# [[ 42 104]
#  [ 42  97]]
#  Train  0.494
# [[200 269]
#  [ 53 331]]
# Test  0.495
# [[ 44 102]
#  [ 44  95]]
#  Train  0.495
# [[213 256]
#  [ 62 322]]
# Test  0.496
# [[52 94]
#  [54 85]]
#  Train  0.496
# [[250 219]
#  [ 84 300]]
# Test  0.497
# [[73 73]
#  [77 62]]
#  Train  0.497
# [[316 153]
#  [123 261]]
# Test  0.498
# [[75 71]
#  [81 58]]
#  Train  0.498
# [[328 141]
#  [129 255]]
# Test  0.499
# [[89 57]
#  [95 44]]
#  Train  0.499
# [[371  98]
#  [175 209]]
