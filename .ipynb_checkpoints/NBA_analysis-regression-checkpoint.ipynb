# %%
from sklearn.ensemble import  AdaBoostRegressor
from sklearn.model_selection import train_test_split, cross_val_score
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV, LinearRegression
from sklearn.model_selection import GridSearchCV

# %matplotlib inline

# %%
#Bring in the data

nba = pd.read_csv('./data/nba_analysis_data.csv')
nba.dropna(inplace = True)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8668 entries, 7 to 10684
# Columns: 450 entries, dataset to playoff_game
# dtypes: float64(133), int64(310), object(7)
# memory usage: 29.8+ MB

# %%
X = nba.drop(columns = ['cover','home_win_margin', 'win_margin_ratio',
                        'date', 'dataset','line_cv',
                       'home_starter5',
                       'away_starter2', 'away_starter3',
                       'away_starter4', 'away_starter5',])
y = nba['home_win_margin']

# %%
#splitting data for a train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y , 
                                                    random_state = 22)

# %%
#scaling data to use in various other methods
ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:617: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   after removing the cwd from sys.path.

# %%
from sklearn.decomposition import PCA

# %%
pc = PCA(n_components=250)
X_train_pc = pc.fit_transform(X_train_scaled)
X_test_pc = pc.transform(X_test_scaled)

# %%
var_exp = pc.explained_variance_ratio_
print('Explained variance:            ', var_exp)

cum_var_exp = np.cumsum(var_exp)
print('Cumulative explained variance: ', cum_var_exp)
# Out:
# Explained variance:             [0.03397576 0.02803731 0.01615593 0.01537717 0.01437822 0.01163618
#  0.01052321 0.0093413  0.00898226 0.00740694 0.00729409 0.00712005
#  0.0065715  0.00640375 0.00624423 0.00558314 0.00514161 0.00492726
#  0.0047967  0.00465398 0.00453132 0.00444615 0.00432055 0.00421699
#  0.00408308 0.00401065 0.00398041 0.00389624 0.00387989 0.00381424
#  0.00375717 0.0037244  0.00369661 0.0036676  0.00365007 0.00362515
#  0.00359749 0.00358318 0.00356252 0.00351218 0.0035086  0.00348606
#  0.00347732 0.00346057 0.0034308  0.00341621 0.00340687 0.00336413
#  0.00335932 0.00333651 0.00331044 0.00330513 0.00327745 0.00327149
#  0.00326055 0.00325566 0.0032212  0.00321563 0.00321098 0.00319183
#  0.0031786  0.00317604 0.00315544 0.00313361 0.00312997 0.00311423
#  0.00311305 0.00309336 0.00307648 0.00306541 0.0030611  0.003047
#  0.00304526 0.00303313 0.00302666 0.00301874 0.00300789 0.00299942
#  0.00299554 0.00298121 0.00296422 0.00295309 0.00294523 0.00293707
#  0.00292558 0.00292421 0.00291435 0.00290911 0.00289199 0.00288285
#  0.00287143 0.00286448 0.00285619 0.00284824 0.00283777 0.00282878
#  0.00282515 0.00281829 0.00280999 0.00280287 0.00279513 0.00278914
#  0.00278732 0.00277331 0.00276752 0.0027599  0.00275061 0.00274495
#  0.00273052 0.00272397 0.00271671 0.00271475 0.00269913 0.00269311
#  0.00268073 0.00267269 0.00267148 0.00266263 0.00265254 0.00264526
#  0.0026364  0.00263015 0.00262809 0.00262058 0.00261442 0.00260942
#  0.00260396 0.00259817 0.00258903 0.00258189 0.00257868 0.00256869
#  0.00256438 0.00256207 0.00255425 0.0025421  0.00252922 0.00252041
#  0.00251399 0.00251018 0.00250146 0.00249559 0.00248579 0.00248299
#  0.00248043 0.00247508 0.00246946 0.00246822 0.00246113 0.00245387
#  0.00244225 0.00244026 0.00242913 0.00241894 0.00241745 0.00241577
#  0.59637005 0.59884513 0.60131459 0.60378281 0.60624394 0.60869781
#  0.61114006 0.61358031 0.61600944 0.61842839 0.62084584 0.62326161
#  0.62566684 0.62806746 0.63046471 0.63284847 0.63522472 0.63759786
#  0.63996775 0.64233169 0.64468412 0.6470317  0.64937416 0.65171385
#  0.65404861 0.65637157 0.65868976 0.66100148 0.6633068  0.66560571
#  0.66790011 0.67019012 0.67246561 0.67473816 0.6770071  0.67926489
#  0.68152098 0.68377298 0.68601605 0.68825557 0.69049024 0.69271834
#  0.69493814 0.69715533 0.69936529 0.70157095 0.70376962 0.70596592
#  0.70815853 0.71034763 0.71252095 0.71469019 0.71685596 0.71901993
#  0.72117143 0.72331711 0.72545677 0.72759354 0.72972212 0.73184811
#  0.73396527 0.73607232 0.73816859 0.7402631  0.74234563 0.74442367
#  0.7464975  0.74856526 0.75062768 0.75268851 0.75473975 0.75678432
#  0.75882435 0.76085946 0.76289051 0.7649106  0.76692523 0.76893086
#  0.77093512 0.77293077 0.77491796 0.77690143 0.77888033 0.78085385
#  0.7828217  0.78478183 0.78672937 0.78866629 0.7905944  0.79251851
#  0.79443537 0.79633755 0.79823676 0.80013045 0.80201039 0.80388068
#  0.80574074 0.80759834 0.80944985 0.81128981 0.81311223 0.81493146
#  0.81673599 0.81853133 0.82031581 0.82209341]

# %% [markdown]
# ### Linear Regression

# %%
ols = LinearRegression()
ols.fit(X_train_pc, y_train)
ols.score(X_train_pc, y_train)
# Out:
# 0.21914273242048277

# %%
ols.score(X_test_pc, y_test)
# Out:
# 0.1655102722748597

# %% [markdown]
# ### Boosting

# %%
ad = AdaBoostRegressor()
ad_params = { 'n_estimators'      : [300],
             'learning_rate'         : [ .01 ],
             
            }

# %%
gs = GridSearchCV(ad, param_grid= ad_params)
gs.fit(X_train_pc, y_train)
print(gs.best_params_)
print(gs.best_score_)
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'learning_rate': 0.01, 'n_estimators': 300}
# 0.10029527888796883

# %%
gs.score(X_test_pc,y_test)
# Out:
# 0.1182594340047639

# %%
y_hat_ad = gs.predict(X_test_pc)

# %%
rr = RidgeCV(alphas = [40, 120, 80])

# %%
rr.fit(X_train_pc, y_train);

# %%
rr.score(X_train_pc, y_train)
# Out:
# 0.21912713268816963

# %%
rr.score(X_test_pc, y_test)
# Out:
# 0.16653212210174384

# %%
rr.coef_
# Out:
# array([ 7.56652318e-01, -8.24964943e-01,  9.47080441e-01, -2.97513231e-01,
#         1.74778231e-01, -4.06442335e-01,  3.33005536e-01, -1.90079136e-01,
#        -6.33419533e-02, -2.80730967e-01, -2.46952371e-01,  5.91970688e-01,
#        -2.14386057e-01,  4.67057804e-01, -6.57929889e-01, -3.41440187e-01,
#         6.34210793e-03, -4.14117960e-01,  1.98379368e-01, -7.26068308e-02,
#         1.72044067e-01,  2.91662272e-01, -2.57331616e-01,  2.13486436e-01,
#        -2.27809730e-01,  3.19907112e-01,  4.39712399e-01,  4.10390191e-02,
#        -2.14809290e-01,  2.56857299e-01, -1.32293248e-01, -5.11214029e-02,
#        -1.10922157e-01, -1.57581633e-01,  9.11721608e-02,  1.08314132e-01,
#        -4.39540086e-01, -8.49641225e-03, -2.32985925e-01,  2.85114499e-01,
#        -2.08498762e-01,  9.86894595e-03, -1.31597819e-01,  1.52582992e-01,
#        -2.02956233e-01, -6.59162995e-02,  7.63703999e-02, -5.48118732e-02,
#        -6.81422886e-02,  2.24811071e-01, -1.76657966e-01,  2.88761712e-02,
#         2.06682321e-01,  1.50431666e-01,  2.77010795e-02,  1.01101170e-01,
#        -7.54677797e-02,  1.23887440e-01,  2.37235198e-01,  2.54378615e-01,
#        -5.54374002e-02, -3.17598857e-02,  6.89394375e-02,  3.81690999e-01,
#        -3.84548274e-01,  2.01894840e-01,  9.46133310e-02,  1.73516825e-01,
#         2.81471264e-01,  7.57184664e-02,  3.10113135e-01,  2.28356857e-01,
#         3.76970377e-01,  2.26083591e-02,  4.52744686e-03,  3.67949278e-02,
#        -2.90144061e-01, -8.52758431e-02, -2.57142533e-01, -1.21787400e-01,
#        -4.71848424e-04,  2.36626830e-01, -3.15775435e-01,  2.58406437e-01,
#        -9.77830725e-02,  1.44109577e-01,  1.29475160e-02, -2.45173628e-02,
#         2.60605302e-01,  7.20878183e-02,  1.09025241e-01,  1.43069593e-02,
#        -2.02254471e-02, -9.23422299e-02, -7.87548644e-02, -4.77203604e-01,
#         1.47756404e-02, -2.96415725e-01,  1.47804389e-01,  4.71486258e-02,
#         2.47270241e-01,  1.84903466e-01,  1.70779955e-02,  6.68048668e-01,
#         1.74160330e-01,  1.56507878e-01])

# %%
y_hat_rr = rr.predict(X_test_pc)

# %%
rr.alpha_
# Out:
# 120

# %%
y_hat_rr
# Out:
# array([10.57024481, -0.4486354 , -3.45377681, ...,  0.945034  ,
#         1.84048332,  3.86654862])

# %% [markdown]
# ### Support Vector Machine

# %%
svm = SVR()
svm_params = {'kernel' : ['linear'],
              'C'      : [.1, .02, .05]}

# %%
gs = GridSearchCV(svm, param_grid= svm_params)
gs.fit(X_train_pc, y_train)
print(gs.best_params_)
print(gs.best_score_)
# Out:
# /Users/bryancombs/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
gs.score(X_test_pc, y_test)

# %%
y_hat_svm = gs.predict(X_test_pc)

# %% [markdown]
# ### Neural Network
#
# Going to fit a neural network with the X features.   I am not concerned about inference.  Accurate prediction is all that matters.  So am going to set up an neural network as one of the final predictors of Home Win Margin.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %%
model = Sequential()
model.add(Dense(250, 
                activation = 'relu',
                input_dim = X_train_pc.shape[1]))
#model.add(Dense(18, activation = 'relu'))

model.add(Dense(1, activation = None)) #output layer

# %%
model.compile(loss = 'mean_squared_error', optimizer='adam' )
model.fit(X_train_pc, 
          y_train, epochs =18, 
          batch_size= 64, 
          validation_data=(X_test_pc, y_test))
# Out:
# Train on 6847 samples, validate on 2283 samples
# Epoch 1/18
# 6847/6847 [==============================] - 0s 39us/step - loss: 136.7366 - val_loss: 140.5807
# Epoch 2/18
# 6847/6847 [==============================] - 0s 17us/step - loss: 136.6357 - val_loss: 140.5447
# Epoch 3/18
# 6847/6847 [==============================] - 0s 17us/step - loss: 136.5802 - val_loss: 140.5191
# Epoch 4/18
# 6847/6847 [==============================] - 0s 19us/step - loss: 136.5781 - val_loss: 140.5094
# Epoch 5/18
# 6847/6847 [==============================] - 0s 21us/step - loss: 136.5225 - val_loss: 140.5074
# Epoch 6/18
# 6847/6847 [==============================] - 0s 21us/step - loss: 136.4155 - val_loss: 140.5671
# Epoch 7/18
# 6847/6847 [==============================] - 0s 22us/step - loss: 136.3637 - val_loss: 140.4712
# Epoch 8/18
# 6847/6847 [==============================] - 0s 21us/step - loss: 136.2798 - val_loss: 140.5650
# Epoch 9/18
# 6847/6847 [==============================] - 0s 20us/step - loss: 136.2737 - val_loss: 140.5140
# Epoch 10/18
# 6847/6847 [==============================] - 0s 22us/step - loss: 136.1900 - val_loss: 140.5159
# Epoch 11/18
# 6847/6847 [==============================] - 0s 21us/step - loss: 136.1320 - val_loss: 140.4625
# Epoch 12/18
# 6847/6847 [==============================] - 0s 20us/step - loss: 136.0958 - val_loss: 140.5358
# Epoch 13/18
# 6847/6847 [==============================] - 0s 18us/step - loss: 136.0390 - val_loss: 140.5175
# Epoch 14/18
# 6847/6847 [==============================] - 0s 20us/step - loss: 135.9671 - val_loss: 140.4966
# Epoch 15/18
# 6847/6847 [==============================] - 0s 21us/step - loss: 135.9270 - val_loss: 140.5208
# Epoch 16/18
# 6847/6847 [==============================] - 0s 20us/step - loss: 135.8493 - val_loss: 140.5944
# Epoch 17/18
# 6847/6847 [==============================] - 0s 19us/step - loss: 135.7772 - val_loss: 140.5384
# Epoch 18/18
# 6847/6847 [==============================] - 0s 20us/step - loss: 135.7298 - val_loss: 140.5688

# %%
y_hat_nn = model.predict(X_test_pc)
predictions = pd.DataFrame(y_hat_nn, columns= ['y_hat_nn'])
predictions
# Out:
#        y_hat_nn
# 0      7.768983
# 1      4.021528
# 2      8.243096
# 3     11.663681
# 4      5.408768
# 5     -9.989044
# 6     -0.168817
# 7      5.903172
# 8      1.811391
# 9      1.966661
# 10     0.504260
# 11    11.085077
# 12     9.797791
# 13     7.266592
# 14     4.275359
# 15     3.102518
# 16     6.668822
# 17    -1.053529
# 18    -4.983622
# 19     9.095721
# 20    -8.401645
# 21    -0.290977
# 22     1.167820
# 23    -7.081255
# 24    11.094003
# 25    10.094916
# 26     8.592352
# 27    10.408021
# 28     4.417334
# 29     2.063282
# ...         ...
# 2253   9.059849
# 2254   1.555678
# 2255  13.762412
# 2256   1.164597
# 2257  -9.206629
# 2258  -3.159900
# 2259   6.051614
# 2260  -9.849234
# 2261   3.140860
# 2262   4.478661
# 2263   6.747016
# 2264  10.303628
# 2265 -12.151544
# 2266  11.128678
# 2267   2.777592
# 2268  -1.499394
# 2269   7.548583
# 2270  -6.226259
# 2271  -2.074780
# 2272  -1.710311
# 2273   9.752079
# 2274  -4.293295
# 2275   7.495342
# 2276   8.425525
# 2277   7.720726
# 2278  15.529154
# 2279   1.595838
# 2280   8.797223
# 2281   6.442422
# 2282  -7.643123
#
# [2283 rows x 1 columns]

# %%
predictions['y_hat_rr'] = y_hat_rr
predictions['y_hat_svm'] = y_hat_svm
predictions['y_hat_ad'] = y_hat_ad

# %%
predictions.head(10)
# Out:
#     y_hat_nn   y_hat_rr  y_hat_svm   y_hat_ad
# 0   7.768983   8.509132   8.250464   4.735949
# 1   4.021528   3.897451   4.478983   2.877500
# 2   8.243096   7.939707   8.107149   3.555861
# 3  11.663681  11.328191  11.579659  10.019220
# 4   5.408768   5.281882   6.085489   8.884793
# 5  -9.989044 -10.463134 -11.088128  -4.960184
# 6  -0.168817   0.824683   0.352110   2.206829
# 7   5.903172   5.726796   5.802836  -0.168979
# 8   1.811391   2.196907   2.599390   6.310578
# 9   1.966661   1.828906   1.874987   3.826923

# %%
y_s = pd.DataFrame(y_test)
y_s.reset_index(inplace = True)
predictions['y_test'] = y_s['home_win_margin']
predictions.head()
# Out:
#     y_hat_nn   y_hat_rr  y_hat_svm   y_hat_ad  y_test
# 0   7.768983   8.509132   8.250464   4.735949    15.0
# 1   4.021528   3.897451   4.478983   2.877500    21.0
# 2   8.243096   7.939707   8.107149   3.555861    15.0
# 3  11.663681  11.328191  11.579659  10.019220     9.0
# 4   5.408768   5.281882   6.085489   8.884793     7.0

# %%
X_test.reset_index(inplace = True)
predictions['spread'] = X_test['spread']
predictions
# Out:
#        y_hat_nn   y_hat_rr  y_hat_svm   y_hat_ad  y_test  spread
# 0      7.768983   8.509132   8.250464   4.735949    15.0    -8.0
# 1      4.021528   3.897451   4.478983   2.877500    21.0    -4.0
# 2      8.243096   7.939707   8.107149   3.555861    15.0    -8.0
# 3     11.663681  11.328191  11.579659  10.019220     9.0   -12.0
# 4      5.408768   5.281882   6.085489   8.884793     7.0    -5.5
# 5     -9.989044 -10.463134 -11.088128  -4.960184   -16.0     8.5
# 6     -0.168817   0.824683   0.352110   2.206829   -11.0    -2.5
# 7      5.903172   5.726796   5.802836  -0.168979     2.0    -6.5
# 8      1.811391   2.196907   2.599390   6.310578    25.0    -2.0
# 9      1.966661   1.828906   1.874987   3.826923   -15.0    -2.5
# 10     0.504260   0.264940   0.035816  -0.969965   -10.0     0.0
# 11    11.085077  10.515366  10.502223  10.114595    -1.0   -10.5
# 12     9.797791   9.696196   9.949120  12.142509     3.0   -10.0
# 13     7.266592   4.858778   4.253523   2.677083     7.0    -7.0
# 14     4.275359   4.411244   4.706203   3.582579    -6.0    -4.5
# 15     3.102518   3.762390   3.471064   0.428971    11.0    -4.5
# 16     6.668822   7.105863   6.762394   7.842257    -6.0    -8.0
# 17    -1.053529  -2.331965  -2.535982   3.108173   -12.0     2.0
# 18    -4.983622  -6.177223  -6.368827  -1.849973     4.0     6.0
# 19     9.095721   8.406658   8.596375   7.589147    22.0    -8.5
# 20    -8.401645  -7.100525  -7.651913  -3.396005   -20.0     6.5
# 21    -0.290977  -1.037328  -0.357602  -0.594828     1.0     1.0
# 22     1.167820   2.153710   1.919781  -0.796973    17.0    -4.0
# 23    -7.081255  -6.899754  -7.200595  -5.348101    -6.0     6.5
# 24    11.094003  10.217793  10.266295   9.205993     1.0   -11.5
# 25    10.094916   9.665637  10.161439   8.108761    24.0   -10.5
# 5   -9.989044 -10.463134 -11.088128  -4.960184   -16.0     8.5 -10.147074
# 6   -0.168817   0.824683   0.352110   2.206829   -11.0    -2.5   0.162350
# 7    5.903172   5.726796   5.802836  -0.168979     2.0    -6.5   5.844380
# 8    1.811391   2.196907   2.599390   6.310578    25.0    -2.0   1.939896
# 9    1.966661   1.828906   1.874987   3.826923   -15.0    -2.5   1.920743
# 10   0.504260   0.264940   0.035816  -0.969965   -10.0     0.0   0.424487
# 11  11.085077  10.515366  10.502223  10.114595    -1.0   -10.5  10.895174
# 12   9.797791   9.696196   9.949120  12.142509     3.0   -10.0   9.763926
# 13   7.266592   4.858778   4.253523   2.677083     7.0    -7.0   6.463987
# 14   4.275359   4.411244   4.706203   3.582579    -6.0    -4.5   4.320654
# 15   3.102518   3.762390   3.471064   0.428971    11.0    -4.5   3.322475
# 16   6.668822   7.105863   6.762394   7.842257    -6.0    -8.0   6.814502
# 17  -1.053529  -2.331965  -2.535982   3.108173   -12.0     2.0  -1.479674
# 18  -4.983622  -6.177223  -6.368827  -1.849973     4.0     6.0  -5.381489
# 19   9.095721   8.406658   8.596375   7.589147    22.0    -8.5   8.866034

# %%
predictions['predict_svm'] =  (predictions.y_hat_svm + predictions.spread).map(
    lambda x: 0 if x <0 else 1)

# %%
predictions['predict_ad'] =  (predictions.y_hat_ad + predictions.spread).map(
    lambda x: 0 if x <0 else 1)

# %%
predictions['predict_rr'] =  (predictions.y_hat_rr + predictions.spread).map(
    lambda x: 0 if x <0 else 1)

# %%
predictions['predict_nn'] =  (predictions.y_hat_nn + predictions.spread).map(
    lambda x: 0 if x <0 else 1)

# %%
predictions['actual'] = (predictions.y_test + predictions.spread).map(lambda x: 0 if x< 0 else 1)

# %%
predictions['predict'] = (predictions['predict_svm']+ 
    predictions['predict_rr'] + predictions['predict_nn'])

# %%
predictions.head()
# Out:
#     y_hat_nn   y_hat_rr  y_hat_svm   y_hat_ad  y_test  spread  y_hat_ave  \
# 0   7.768983   8.509132   8.250464   4.735949    15.0    -8.0   8.015699
# 1   4.021528   3.897451   4.478983   2.877500    21.0    -4.0   3.980169
# 2   8.243096   7.939707   8.107149   3.555861    15.0    -8.0   8.141967
# 3  11.663681  11.328191  11.579659  10.019220     9.0   -12.0  11.551851
# 4   5.408768   5.281882   6.085489   8.884793     7.0    -5.5   5.366473
#
#    predict_svm  predict_ad  predict_rr  predict_nn  actual  predict
# 0            1           0           1           0       1        2
# 1            1           0           0           1       1        2
# 2            1           0           0           1       1        2
# 3            0           0           0           0       0        0
# 4            1           1           0           0       1        1

# %%
print(classification_report(predictions.actual, predictions.predict_rr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.70      0.57      1119
#            1       0.50      0.29      0.36      1164
#
#    micro avg       0.49      0.49      0.49      2283
#    macro avg       0.49      0.49      0.47      2283
# weighted avg       0.49      0.49      0.47      2283

# %%
confusion_matrix(predictions.actual, predictions.predict_svm)
# Out:
# array([[778, 341],
#        [812, 352]])

# %%
predictions.predict.value_counts(normalize = True)
# Out:
# 0    0.515550
# 1    0.197547
# 3    0.168200
# 2    0.118703
# Name: predict, dtype: float64

# %%
predictions.groupby(['predict'])['actual'].mean()
# Out:
# predict
# 0    0.508071
# 1    0.516630
# 2    0.509225
# 3    0.507812
# Name: actual, dtype: float64
